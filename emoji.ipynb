# %% [markdown]
# ### Import token

# %%
import facebook
import progressbar
import datetime

def get_emoji(token, id_num):
    emoji_time = {}
    graph = facebook.GraphAPI(access_token = token, version = 2.7)
    post = graph.get_object(id='{}?fields=video_insights'.format(id_num))
    emoji_value = post['video_insights']['data'][-1]['values'][0]['value']
    time = datetime.datetime.now()
    emoji_time[time.isoformat(" ")] = emoji_value
    emoji_list.append(emoji_time)
    
def get_video_status(id_num):
    graph = facebook.GraphAPI(access_token = token, version = 2.7)
    post = graph.get_object(id='{}?fields=live_status'.format(id_num))
    live_status = post['live_status']
    return(live_status)

# %% [markdown]
# # group 1

# %%
import time as tt
import pickle

bar = progressbar.ProgressBar(max_value=progressbar.UnknownLength)
token = 'EAACEdEose0cBAKaLISweOkaCCD9qilAACWDnRNM7rLyR3I4aIHwfD8XshUUFbZAxBw9Ylo6CWGM4addVZAsZC0J8sTztrNQtPaQIVz5DPBInwHq16iHOZCr5VZBJeJH8g4UIZB2ZCmmRLjYoHqyZClxRGZBOkd4qQ9e5tXrCgidHncwAbZB7XlOHv1xnPZA8YYGcmcZD' 
id_num = "233936170421968"
emoji_list = []
count = 1


while True:
    get_emoji(token, id_num)
    get_video_status(id_num)
    if get_video_status(id_num) == "VOD":
        break
    bar.update(count)
    count += 1
    #tt.sleep(1)
    
data_1 = pickle.dump(emoji_list, open("group_1_emoji.txt", "wb"))
# Out:
# / 1045 Elapsed Time: 0:23:17

# %%
for value in emoji_list:
    print(value)
# Out:
# {'2017-05-05 09:29:48.648696': {'sorry': 0, 'wow': 0, 'like': 2, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 09:29:49.974334': {'sorry': 0, 'wow': 0, 'like': 2, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 09:29:51.407626': {'sorry': 0, 'wow': 0, 'like': 2, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 09:29:52.615088': {'sorry': 0, 'wow': 0, 'like': 2, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 09:29:53.864708': {'sorry': 0, 'wow': 0, 'like': 2, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 09:29:55.196614': {'sorry': 0, 'wow': 0, 'like': 2, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 09:29:56.451539': {'sorry': 0, 'wow': 0, 'like': 2, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 09:29:57.758868': {'sorry': 0, 'wow': 0, 'like': 2, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 09:29:59.906745': {'sorry': 0, 'wow': 0, 'like': 2, 'anger': 0, 'haha': 0, 'love': 0}}
# ...

# %% [markdown]
# # group 2

# %%
import time as tt
import pickle

bar = progressbar.ProgressBar(max_value=progressbar.UnknownLength)
token = 'EAACEdEose0cBAKdWaobFNydsBQH8jPIEUihBOGBzQX3usNE4KJDCfImuwZCLT7NdzXO4wVwQavjEnnodW2nCCkCsJJCZBwNc8ISI1oQzu6K3HvX3bODv4vZBZCuOMfwW7l1HZBWSZBFNehbVUZAcqIK2fCSZCGJEQfkGLquarhQPCG4WRAu6ntzkaaGVmcqAZCZBQZD' 
id_num = "233945870420998"
emoji_list = []
count = 1


while True:
    get_emoji(token, id_num)
    get_video_status(id_num)
    if get_video_status(id_num) == "VOD":
        break
    bar.update(count)
    count += 1
    #tt.sleep(1)
    
data_2 = pickle.dump(emoji_list, open("group_2_emoji.txt", "wb"))
# Out:
# - 682 Elapsed Time: 0:13:36

# %%
for value in emoji_list:
    print(value)
# Out:
# {'2017-05-05 10:09:08.437449': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:09:09.423430': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:09:10.364677': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:09:11.222421': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:09:12.063194': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:09:12.873186': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:09:13.688646': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:09:14.562881': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:09:15.380521': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# ...

# %% [markdown]
# # group 3

# %%
import time as tt
import pickle

bar = progressbar.ProgressBar(max_value=progressbar.UnknownLength)
token = 'EAACEdEose0cBALQNzbQbZCisZCaZB1dLVfEo8dF4Ci2pBuvnUDrYd8iJMmSuuG8YlDN0wiVRYxl59L8lfQ2ErMLRjm07ZBw9ZAV6wUvsAZC2Mhv5cYvBJ1LTus2BUdQ6ZCcZC64graphHfV41YAl7NlgaQDjUSjvufwJWQ68rZAVDcROx2FRsyUxZAJSpWo6SAaFUZD' 
id_num = "233953213753597"
emoji_list = []
count = 1


while True:
    get_emoji(token, id_num)
    get_video_status(id_num)
    if get_video_status(id_num) == "VOD":
        break
    bar.update(count)
    count += 1
    #tt.sleep(1)
    
data_3 = pickle.dump(emoji_list, open("group_3_emoji.txt", "wb"))
# Out:
# / 993 Elapsed Time: 0:21:39

# %%
for value in emoji_list:
    print(value)
# Out:
# {'2017-05-05 10:40:32.317885': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:40:33.546813': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:40:35.066124': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:40:36.367035': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:40:37.729259': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:40:39.387972': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:40:41.159869': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:40:43.555715': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 10:40:45.481669': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# ...

# %% [markdown]
# # group 4

# %%
import time as tt
import pickle

bar = progressbar.ProgressBar(max_value=progressbar.UnknownLength)
token = 'EAACEdEose0cBANapj9ymeG7myFvhYBxMLWmNa4FMUpjk8oKBukWuDMeLGoLkRirPOgDKRHfNHlDVikxZCWK7O4ZA0d8gnSmc8Vqs9k2m30e8MEEdrCeras4EewARzJ32lJSoGXMkIJ1AAA5g7UXL6qs9r41WWIDq0GqZAMjVxU6mEokBHS4k4ilPZBYxkOgZD' 
id_num = "233967070418878"
emoji_list = []
count = 1


while True:
    get_emoji(token, id_num)
    get_video_status(id_num)
    if get_video_status(id_num) == "VOD":
        break
    bar.update(count)
    count += 1
    #tt.sleep(1)
    
data_4 = pickle.dump(emoji_list, open("group_4_emoji.txt", "wb"))
# Out:
# / 725 Elapsed Time: 0:16:00

# %%
for value in emoji_list:
    print(value)
# Out:
# {'2017-05-05 11:18:15.869387': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 11:18:17.226705': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 11:18:18.500376': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 11:18:19.729762': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 11:18:21.275412': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 11:18:22.494266': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 11:18:23.893924': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 11:18:25.109849': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# {'2017-05-05 11:18:27.484924': {'sorry': 0, 'wow': 0, 'like': 0, 'anger': 0, 'haha': 0, 'love': 0}}
# ...
