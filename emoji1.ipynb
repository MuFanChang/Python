# %% [markdown]
# ### Import token

# %%
import facebook
import progressbar
import datetime

def get_emoji(token, id_num):
    emoji_time = {}
    graph = facebook.GraphAPI(access_token = token, version = 2.7)
    post = graph.get_object(id='{}?fields=video_insights'.format(id_num))
    emoji_value = post['video_insights']['data'][-1]['values'][0]['value']
    time = datetime.datetime.now()
    emoji_time[time.isoformat(" ")] = emoji_value
    emoji_list.append(emoji_time)
    
def get_video_status(id_num):
    graph = facebook.GraphAPI(access_token = token, version = 2.7)
    post = graph.get_object(id='{}?fields=live_status'.format(id_num))
    live_status = post['live_status']
    return(live_status)

# %% [markdown]
# # group 1

# %%
import time as tt
import pickle

bar = progressbar.ProgressBar(max_value=progressbar.UnknownLength)
token = 'EAACEdEose0cBAKkM74q2d5DzsUQjur66iZBmXXRVe3SxMeYDC8pUXWQgfU55EB4qb1hzy8SMhKSp2RvsW48FJjnopdJiSjHv8z6QuArdLIzSi3EQefiNyuWVIwV8BmG7ZCa2ZBQxrDe2z6ZCMZC7G7crxBVv9Vj5k6WcvsZAS5I1wSwS29WK5fKZB2rfDlfMCIZD' 
id_num = "233936170421968"
emoji_list = []
count = 1


while True:
    get_emoji(token, id_num)
    get_video_status(id_num)
    if get_video_status(id_num) == "VOD":
        break
    bar.update(count)
    count += 1
    #tt.sleep(1)
    
data_5 = pickle.dump(emoji_list, open("group_5_emoji.txt", "wb"))

# %%
for value in emoji_list:
    print(value)

# %% [markdown]
# # group 2

# %%
import time as tt
import pickle

bar = progressbar.ProgressBar(max_value=progressbar.UnknownLength)
token = 'EAACEdEose0cBAImw5Pg8rAx8LfZA0RByKRxbMpOB2avGhDpeRsqSgsQNhMB48Y1KEYbYwLEJZA6rKPSP6kC5cn61C7PVcsYYswJJc1PrE0edTPevnCaEvg0896W3gDEZBj9GVkfZABoN5nISHWYqWgWRhgvwGysYZBHgidQBlHqyXw3Y0ZCB8T3QhNztq9n8QZD' 
id_num = "236397393509179"
emoji_list = []
count = 1


while True:
    get_emoji(token, id_num)
    get_video_status(id_num)
    if get_video_status(id_num) == "VOD":
        break
    bar.update(count)
    count += 1
    #tt.sleep(1)
    
data_6 = pickle.dump(emoji_list, open("group_6_emoji.txt", "wb"))
# Out:
# | 1220 Elapsed Time: 0:22:18

# %%
for value in emoji_list:
    print(value)
# Out:
# {'2017-05-10 16:53:46.741743': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 16:53:47.972970': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 16:53:49.300273': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 16:53:50.628257': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 16:53:51.890122': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 16:53:53.122188': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 16:53:54.419084': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 16:53:55.750074': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 16:53:56.954912': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# ...

# %% [markdown]
# # group 3

# %%
import time as tt
import pickle

bar = progressbar.ProgressBar(max_value=progressbar.UnknownLength)
token = 'EAACEdEose0cBAEOOZBMC56PViIV81v65eISekE7sXCvrw9xXwAWHq1hqLZA1RKD9Vg8nTZCOZBMKfVp1yEVQ88hZARJjKWLug16ZBiioOMtNJnMmEZAdnnralkkkLZAD6VluEbIvxgtXIvLtRHgzHWzXvCZCZBZBFPOhbgLeU8EZBfhlN2JNFzfqmrtgUxvls56v8xUZD' 
id_num = "236405440175041"
emoji_list = []
count = 1


while True:
    get_emoji(token, id_num)
    get_video_status(id_num)
    if get_video_status(id_num) == "VOD":
        break
    bar.update(count)
    count += 1
    #tt.sleep(1)
    
data_7 = pickle.dump(emoji_list, open("group_7_emoji.txt", "wb"))
# Out:
# - 1002 Elapsed Time: 0:19:41

# %%
for value in emoji_list:
    print(value)
# Out:
# {'2017-05-10 17:31:45.558529': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 17:31:46.435935': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 17:31:47.297276': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 17:31:48.115307': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 17:31:48.956075': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 17:31:49.762577': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 17:31:50.590931': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 17:31:51.400028': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# {'2017-05-10 17:31:52.226879': {'anger': 0, 'sorry': 0, 'wow': 0, 'haha': 0, 'like': 0, 'love': 0}}
# ...
